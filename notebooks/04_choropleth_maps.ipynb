# %% [markdown]
# # Global Carbon Pricing Maps
#
# "#Map" section. R used `rworldmap`; here `plotly` choropleths (ISO-3 matched) stand in, exported as static PNGs.
#
# Note: the R draft filters `Year == 2024` but titles both maps "(2023)" -- reproduced literally.

# %%
import sys
sys.path.append('..')

from src import config as cfg
from src.preprocessing import build_merged_data
from src import mapping

merged_data = build_merged_data()

# %% [markdown]
# ## Global Carbon Tax Intensity

# %%
fig = mapping.plot_carbon_tax_map(merged_data, save_path=cfg.FIGURES_DIR / 'map_carbon_tax.png')
fig.show()

# %% [markdown]
# ## Global ETS Intensity

# %%
fig = mapping.plot_ets_map(merged_data, save_path=cfg.FIGURES_DIR / 'map_ets.png')
fig.show()
